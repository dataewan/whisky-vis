# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Load the data.

# %%
whiskies = (
    pd.read_csv('../whiskies.txt')
    .pipe(lambda x: x.assign(Postcode = x.Postcode.str.strip()))
)

# %%
whiskies.head()
# Out:
#    RowID Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# 0      1  Aberfeldy     2          2      2          0        0      2      1
# 1      2   Aberlour     3          3      1          0        0      4      3
# 2      3     AnCnoc     1          3      2          0        0      2      0
# 3      4     Ardbeg     4          1      4          4        0      0      2
# 4      5    Ardmore     2          2      2          0        0      1      1
#
#    Winey  Nutty  Malty  Fruity  Floral  Postcode   Latitude   Longitude
# 0      2      2      2       2       2  PH15 2EB     286580      749680
# 1      2      2      3       3       2  AB38 9PJ     326340      842570
# 2      0      2      2       3       2   AB5 5LI     352960      839320
# 3      0      1      2       1       0  PA42 7EB     141560      646220
# 4      1      2      3       1       1  AB54 4NH     355350      829140

# %%
# These are the dimensions that each whisky is scored on.

dimensions = [
    'Body', 'Sweetness', 'Smoky', 'Medicinal',
       'Tobacco', 'Honey', 'Spicy', 'Winey', 'Nutty', 'Malty', 'Fruity',
       'Floral'
]

# %% [markdown]
# Checking correlations between the whiskies.

# %%
fig, ax = plt.subplots(figsize=(11, 10))

sns.heatmap(
    whiskies[dimensions].corr(),
    xticklabels=dimensions,
    yticklabels=dimensions,
    ax=ax,
    vmin=-1,
    vmax=1,
    center=0,
    cmap=sns.color_palette('RdBu_r', 21)
);

# %% [markdown]
# Performing a factor analysis to even out the effects of correlations.

# %%
from sklearn.decomposition import FactorAnalysis

fa = FactorAnalysis(n_components=6)

factors = pd.DataFrame(fa.fit_transform(whiskies[dimensions]))

# %% [markdown]
# Take a little look around in the components to see that they kind of make sense.

# %%
factor_loadings = (
    pd.DataFrame(data=fa.components_)
)

dimension_cmap = sns.color_palette('Paired', n_colors=len(dimensions))

factor_loadings.columns = dimensions

factor_loadings.plot(color=dimension_cmap, kind='barh', figsize=(8, 10))

# %%
# https://pythonprogramminglanguage.com/kmeans-elbow-method/

from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist

distortions = []

K = range(1,20)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(factors)
    distortions.append(sum(np.min(cdist(factors, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / factors.shape[0])


plt.plot(K, distortions)

# %%
km = KMeans(n_clusters=6, random_state=0).fit(factors)

# %%
whiskies['cluster'] = km.labels_

# %%
whiskies.groupby('cluster').apply(len).plot(kind='bar', color='#401227')

# %%
whiskies.query('cluster==1')
# Out:
#     RowID     Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  \
# 4       5        Ardmore     2          2      2          0        0      1
# 5       6    ArranIsleOf     2          3      1          1        0      1
# 18     19        Bowmore     2          2      3          1        0      2
# 39     40     GlenScotia     2          2      2          2        0      1
# 40     41       GlenSpey     1          3      1          0        0      0
# 52     53     Glenturret     2          3      1          0        0      2
# 53     54  Highland Park     2          2      3          1        0      2
# 54     55      Inchgower     1          3      1          1        0      2
# 55     56   Isle of Jura     2          1      2          2        0      1
# 60     61    Loch Lomond     1          1      1          1        0      1
# 64     65     Miltonduff     2          4      1          0        0      1
# 72     73       Speyburn     2          4      1          0        0      2
# 74     75     Springbank     2          2      2          2        0      2
# 82     83        Tomatin     2          3      2          0        0      2
# 83     84      Tomintoul     0          3      1          0        0      2
# 84     85        Tormore     2          2      1          0        0      1
#
#     Spicy  Winey  Nutty  Malty  Fruity  Floral  Postcode   Latitude  \
# 4       1      1      2      3       1       1  AB54 4NH     355350
# 5       1      1      0      1       1       2  KA27 8HJ     194050
# 18      2      1      1      1       1       2  PA43 7GS     131330
# 39      0      1      2      2       1       1  PA28 6DS     172090
# 40      1      1      1      2       0       2  AB38 7AU     327760
# 52      2      2      2      2       1       2   PH7 4HA     285630
# 53      1      1      1      2       1       1  KW15 1SU     345340
# 54      2      0      1      2       1       2  AB56 5AB     342610
# 55      1      0      2      1       1       1  PA60 7XT     152660
# 60      1      0      1      2       1       2   G83 0TL     239370
# 64      0      0      2      1       1       2  IV30 3TQ     322640
# 72      1      0      0      2       1       2  AB38 7AG     326930
# 74      2      1      2      1       0       1  PA28 6EJ     172280
# 82      2      1      1      2       0       1  IV13 7YT     279120
# 83      2      1      1      2       1       2  AB37 9AQ     315100
# 84      0      1      2      1       0       0  PH26 3LR     315180
#
#      Longitude  cluster
# 4       829140        1
# 5       649950        1
# 18      659720        1
# 39      621010        1
# 40      849140        1
# 52      723580        1
# 53     1009260        1
# 54      863970        1
# 55      667040        1
# 60      680920        1
# 64      861040        1
# 72      851430        1
# 74      620910        1
# 82      829630        1
# 83      825560        1
# 84      834960        1

# %%
(
    whiskies
    [dimensions + ['cluster']]
    .groupby('cluster')
    .agg(np.mean).T
)
# Out:
# cluster           0       1         2     3         4    5
# Body       1.484848  1.6875  1.833333  2.50  3.666667  3.8
# Sweetness  2.272727  2.5000  2.333333  2.35  1.500000  2.4
# Smoky      1.212121  1.5625  1.500000  1.35  3.666667  1.8
# Medicinal  0.303030  0.6875  0.666667  0.10  3.333333  0.0
# Tobacco    0.000000  0.0000  1.000000  0.00  0.666667  0.0
# Honey      0.909091  1.4375  1.000000  1.90  0.166667  1.8
# Spicy      1.212121  1.1875  1.666667  1.60  1.666667  1.6
# Winey      0.454545  0.7500  1.166667  1.55  0.500000  3.2
# Nutty      1.333333  1.3125  1.166667  1.80  1.166667  2.2
# Malty      1.636364  1.6875  2.166667  2.30  1.333333  1.4
# Fruity     2.181818  0.7500  1.500000  2.25  1.166667  2.0
# Floral     2.060606  1.5000  1.833333  1.80  0.166667  1.2

# %% [markdown]
# -----
#
# What about doing the clustering without a PCA first?

# %%
whisky_scores = whiskies[dimensions]

distortions = []

K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(whisky_scores)
    distortions.append(sum(np.min(cdist(whisky_scores, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / whisky_scores.shape[0])

    
plt.plot(K, distortions)

# %%
km = KMeans(n_clusters=6, random_state=0).fit(whisky_scores)

whiskies['plain_cluster'] = km.labels_

# %%
whiskies.groupby('plain_cluster').apply(len).plot(kind='bar', color='#401227')

# %%
(
    whiskies
    [dimensions + ['plain_cluster']]
    .groupby('plain_cluster')
    .agg(np.mean).T
)
# Out:
# plain_cluster         0         1         2     3         4      5
# Body           2.222222  1.454545  3.666667  1.70  1.833333  3.500
# Sweetness      2.444444  2.409091  1.500000  2.60  1.750000  2.250
# Smoky          1.388889  1.045455  3.666667  1.20  2.000000  1.750
# Medicinal      0.055556  0.181818  3.333333  0.25  1.333333  0.125
# Tobacco        0.111111  0.000000  0.666667  0.15  0.083333  0.000
# Honey          2.000000  1.000000  0.166667  1.05  1.083333  1.750
# Spicy          1.666667  0.863636  1.666667  1.60  1.250000  1.625
# Winey          1.444444  0.409091  0.500000  0.80  0.666667  2.750
# Nutty          2.111111  1.681818  1.166667  0.40  1.750000  1.875
# Malty          2.333333  1.636364  1.333333  1.80  1.666667  1.625
# Fruity         1.944444  2.136364  1.166667  1.65  1.166667  2.375
# Floral         2.055556  2.181818  0.166667  1.80  1.166667  1.250

# %%
whiskies.query('plain_cluster == 1')
# Out:
#     RowID    Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  \
#